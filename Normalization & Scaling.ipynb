# %%
import numpy as np
import pandas as pd
from mlxtend.preprocessing import minmax_scaling
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\551461.CTS\AnacondaProjects\MachineLearningWithPython-master\Notebooks\data\pima-data.csv')
df.head(10)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
# 5         5           116            74          0        0  25.6      0.201
# 6         3            78            50         32       88  31.0      0.248
# 7        10           115             0          0        0  35.3      0.134
# 8         2           197            70         45      543  30.5      0.158
# 9         8           125            96          0        0   0.0      0.232
#
#    age    skin  diabetes
# 0   50  1.3790      True
# 1   31  1.1426     False
# 2   32  0.0000      True
# ...

# %%
np.random.seed(0)
scaled_data=minmax_scaling(df,columns=['glucose_conc'])
print(scaled_data.head(10))
df['glucose_conc'].plot(x=df.index.values,y='glucose_conc')
scaled_data.plot(x=scaled_data.index.values,y='glucose_conc')
# Out:
#    glucose_conc
# 0      0.743719
# 1      0.427136
# 2      0.919598
# 3      0.447236
# 4      0.688442
# 5      0.582915
# 6      0.391960
# 7      0.577889
# 8      0.989950
# 9      0.628141

# %%
normalised_data=stats.boxcox(df.glucose_conc[df.glucose_conc>0])
d=pd.DataFrame(normalised_data[0])
d.plot(x=d.index.values,y=0)
